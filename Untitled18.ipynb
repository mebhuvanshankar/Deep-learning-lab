# %% [markdown]
# <a href="https://colab.research.google.com/github/mebhuvanshankar/Deep-learning-lab/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# XOR input and output data
x_train = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_train = np.array([[0], [1], [1], [0]], dtype=np.float32)

# Define the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, input_dim=2, activation='relu'),  # Hidden layer with 8 neurons
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=1000, verbose=0)

# Evaluate the model
loss, accuracy = model.evaluate(x_train, y_train)
print(f"Accuracy: {accuracy}")

# Plotting training progress (loss)
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Plotting training progress (accuracy)
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2254 - accuracy: 1.0000
# Accuracy: 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# XOR input and output data
x_train = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_train = np.array([[0], [1], [1], [0]], dtype=np.float32)

# Define the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, input_dim=2, activation='relu'),  # Hidden layer with 8 neurons
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=1000, verbose=0)

# Evaluate the model
loss, accuracy = model.evaluate(x_train, y_train)
print(f"Accuracy: {accuracy}")

# Create a mesh grid of points
xx, yy = np.meshgrid(np.linspace(-0.5, 1.5, 100), np.linspace(-0.5, 1.5, 100))
input_points = np.c_[xx.ravel(), yy.ravel()]

# Predict outputs for each point in the mesh grid
Z = model.predict(input_points)
Z = Z.reshape(xx.shape)

# Plotting decision boundary
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train.flatten(), cmap=plt.cm.Spectral, edgecolors='k')
plt.title('XOR Problem Decision Boundary')
plt.xlabel('Input 1')
plt.ylabel('Input 2')
plt.show()
# Out:
# 1/1 [==============================] - 1s 774ms/step - loss: 0.2300 - accuracy: 1.0000
# Accuracy: 1.0
# 313/313 [==============================] - 1s 3ms/step
